# %%
import pandas as pd
import numpy as np

# %%
##Loading in the dataset
Housing=pd.read_csv('C:\\Users\\debra\\PYTHON FOLDER\\housing.csv')

# %%
## Analysing the first 10 rows of the dataset to get an overall idea
Housing.head(10)
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 1  12250000   8960         4          4        4      yes        no       no
# 2  12250000   9960         3          2        2      yes        no      yes
# 3  12215000   7500         4          2        2      yes        no      yes
# 4  11410000   7420         4          1        2      yes       yes      yes
# 5  10850000   7500         3          3        1      yes        no      yes
# 6  10150000   8580         4          3        4      yes        no       no
# 7  10150000  16200         5          3        2      yes        no       no
# 8   9870000   8100         4          1        2      yes       yes      yes
# 9   9800000   5750         3          2        4      yes       yes       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
## To find out the data types and no of non-null elements in each row
Housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
## Histogram of Price column to see its distribution . Here we see it is slightly skewed.
# %matplotlib inline 
Housing['price'].hist()
# Out:
# <Axes: >

# %%
#to get an idea of the distribution of data in all the columns
Housing.describe(include='all')
# Out:
#                price          area    bedrooms   bathrooms     stories  \
# count   5.450000e+02    545.000000  545.000000  545.000000  545.000000
# unique           NaN           NaN         NaN         NaN         NaN
# top              NaN           NaN         NaN         NaN         NaN
# freq             NaN           NaN         NaN         NaN         NaN
# mean    4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std     1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min     1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%     3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%     4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%     5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max     1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#        mainroad guestroom basement hotwaterheating airconditioning  \
# ...

# %%
# to find the no of unique values in each column
Housing.nunique()
# Out:
# price               219
# area                284
# bedrooms              6
# bathrooms             4
# stories               4
# mainroad              2
# guestroom             2
# basement              2
# hotwaterheating       2
# airconditioning       2
# parking               4
# prefarea              2
# furnishingstatus      3
# dtype: int64

# %%
## func to plot all the bar chats at once for the categorical columns
def PlotBarCharts(inpData, colsToPlot):
    # %matplotlib inline
    
    import matplotlib.pyplot as plt

    fig, subPlot=plt.subplots(nrows=1, ncols=len(colsToPlot), figsize=(20,5))
    fig.suptitle('Bar charts of: '+ str(colsToPlot))

    for colName, plotNumber in zip(colsToPlot, range(len(colsToPlot))):
        inpData.groupby(colName).size().plot(kind='bar',ax=subPlot[plotNumber])

# %%
Housing.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
## using the function to plot the bar charts
PlotBarCharts(inpData=Housing, colsToPlot=[ 'bedrooms', 'bathrooms', 'stories', 'mainroad',
       'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
       'parking', 'prefarea', 'furnishingstatus'])

# %%
## Histogram of area
Housing.hist('area',figsize=(18,10))
# Out:
# array([[<Axes: title={'center': 'area'}>]], dtype=object)

# %%
len(Housing['area'][Housing['area']>13000])
# Out:
# 4

# %%
Housing['area'][Housing['area']<13000].sort_values(ascending=False)
# Out:
# 403    12944
# 211    12900
# 69     12090
# 129    11460
# 56     11440
#        ...
# 413     1950
# 271     1905
# 527     1836
# 537     1700
# 449     1650
# Name: area, Length: 541, dtype: int64

# %%
## Replacing the outliers to the closest value in order to get rid of it for our machine learning model
Housing['area'][Housing['area']>13000]=12944
# Out:
# C:\Users\debra\AppData\Local\Temp\ipykernel_4928\868105530.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Housing['area'][Housing['area']>13000]=12944

# %%
## now our distribution is uniform
Housing.hist('area',figsize=(18,10))
# Out:
# array([[<Axes: title={'center': 'area'}>]], dtype=object)

# %%
Housing.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
## to see the correlation between area and price, we can conclude they have a positive correlation
Housing.plot.scatter(x='area',y='price',figsize=(10,5))
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
## here we confirm the presence of a positive correlation
columns=['price','area']
Correlationtable=Housing[columns].corr()
Correlationtable
# Out:
#           price      area
# price  1.000000  0.538354
# area   0.538354  1.000000

# %%
## To see the distribution of the categorical columns 
CategoricalColsList=[ 'bedrooms', 'bathrooms', 'stories', 'mainroad',
       'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
       'parking', 'prefarea', 'furnishingstatus']

import matplotlib.pyplot as plt
fig, PlotCanvas=plt.subplots(nrows=1, ncols=len(CategoricalColsList), figsize=(50,10))

for PredictorCol , i in zip(CategoricalColsList, range(len(CategoricalColsList))):
    Housing.boxplot(column='price', by=PredictorCol, figsize=(5,5), vert=True, ax=PlotCanvas[i])

# %%
CategoryGroupLists=[ 'bedrooms', 'bathrooms', 'stories', 'mainroad',
       'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
       'parking', 'prefarea', 'furnishingstatus']

# %%
## function for executing anova test
def FunctionAnova(inpData, TargetVariable, CategoricalPredictorList):
    from scipy.stats import f_oneway

    SelectedPredictors=[]
    
    print('##### ANOVA Results ##### \n')
    for predictor in CategoricalPredictorList:
        CategoryGroupLists=inpData.groupby(predictor)[TargetVariable].apply(list)
        AnovaResults = f_oneway(*CategoryGroupLists)
        
        if (AnovaResults[1] < 0.05):
            print(predictor, 'is correlated with', TargetVariable, '| P-Value:', AnovaResults[1])
            SelectedPredictors.append(predictor)
        else:
            print(predictor, 'is NOT correlated with', TargetVariable, '| P-Value:', AnovaResults[1])
    
    return(SelectedPredictors)

# %%
## Using the function
CategoricalPredictorList=[ 'bedrooms', 'bathrooms', 'stories', 'mainroad',
       'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
       'parking', 'prefarea', 'furnishingstatus']
FunctionAnova(inpData=Housing, TargetVariable='price', CategoricalPredictorList=CategoricalPredictorList)
# Out:
# ##### ANOVA Results #####
#
# bedrooms is correlated with price | P-Value: 5.359905862475199e-18
# bathrooms is correlated with price | P-Value: 2.2723700367467572e-37
# stories is correlated with price | P-Value: 2.6832459713031025e-24
# mainroad is correlated with price | P-Value: 1.4901041488911911e-12
# guestroom is correlated with price | P-Value: 1.429113638558578e-09
# basement is correlated with price | P-Value: 1.1041051901319109e-05
# hotwaterheating is correlated with price | P-Value: 0.029815238966029348
# airconditioning is correlated with price | P-Value: 6.310969853532361e-29
# parking is correlated with price | P-Value: 1.455350625954301e-19
# prefarea is correlated with price | P-Value: 2.7183744670735454e-15
# furnishingstatus is correlated with price | P-Value: 2.0928668857951646e-12
# ['bedrooms',
#  'bathrooms',
#  'stories',
#  'mainroad',
#  'guestroom',
#  'basement',
#  'hotwaterheating',
#  'airconditioning',
#  'parking',
#  'prefarea',
# ...

# %%
## Selected columns from the Anova test
SelectedColumns=[ 'area','bedrooms', 'bathrooms', 'stories', 'mainroad',
       'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
       'parking', 'prefarea', 'furnishingstatus']

DataForML=Housing[SelectedColumns]
DataForML.head()
# Out:
#    area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  7420         4          2        3      yes        no       no
# 1  8960         4          4        4      yes        no       no
# 2  9960         3          2        2      yes        no      yes
# 3  7500         4          2        2      yes        no      yes
# 4  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
import pandas as pd
import numpy as np
from statsmodels.tools.tools import add_constant

# %%
X = add_constant(DataForML)

# %%
##Saving the dataset for Machine Learning
DataForML.to_pickle('DataForML.pkl')

# %%
DataForML=pd.read_pickle('DataForML.pkl')
DataForML.head()
# Out:
#    area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  7420         4          2        3      yes        no       no
# 1  8960         4          4        4      yes        no       no
# 2  9960         3          2        2      yes        no      yes
# 3  7500         4          2        2      yes        no      yes
# 4  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
## Creating dummies for the categorical variables
DataForML_Numeric=pd.get_dummies(DataForML)

DataForML_Numeric['price']=Housing['price']

DataForML_Numeric.head(20)
# Out:
#      area  bedrooms  bathrooms  stories  parking  mainroad_no  mainroad_yes  \
# 0    7420         4          2        3        2        False          True
# 1    8960         4          4        4        3        False          True
# 2    9960         3          2        2        2        False          True
# 3    7500         4          2        2        3        False          True
# 4    7420         4          1        2        2        False          True
# 5    7500         3          3        1        2        False          True
# 6    8580         4          3        4        2        False          True
# 7   12944         5          3        2        0        False          True
# 8    8100         4          1        2        2        False          True
# 9    5750         3          2        4        1        False          True
# 10  12944         3          1        2        2        False          True
# ...

# %%
DataForML_Numeric.columns
# Out:
# Index(['area', 'bedrooms', 'bathrooms', 'stories', 'parking', 'mainroad_no',
#        'mainroad_yes', 'guestroom_no', 'guestroom_yes', 'basement_no',
#        'basement_yes', 'hotwaterheating_no', 'hotwaterheating_yes',
#        'airconditioning_no', 'airconditioning_yes', 'prefarea_no',
#        'prefarea_yes', 'furnishingstatus_furnished',
#        'furnishingstatus_semi-furnished', 'furnishingstatus_unfurnished',
#        'price'],
#       dtype='object')

# %%
## Splitting the data into training and test 
TargetVariable='price'
Predictors=['area', 'bedrooms', 'bathrooms', 'stories', 'parking', 'mainroad_no',
       'mainroad_yes', 'guestroom_no', 'guestroom_yes', 'basement_no',
       'basement_yes', 'hotwaterheating_no', 'hotwaterheating_yes',
       'airconditioning_no', 'airconditioning_yes', 'prefarea_no',
       'prefarea_yes', 'furnishingstatus_furnished',
       'furnishingstatus_semi-furnished', 'furnishingstatus_unfurnished']


X=DataForML_Numeric[Predictors].values
y=DataForML_Numeric[TargetVariable].values


from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=31)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (381, 20)
# (381,)
# (164, 20)
# (164,)

# %%
np.set_printoptions(suppress=True)
X_train[0:10]
# Out:
# array([[6000, 2, 1, 1, 1, False, True, True, False, False, True, True,
#         False, False, True, True, False, True, False, False],
#        [7020, 3, 1, 1, 2, False, True, True, False, False, True, True,
#         False, False, True, False, True, False, True, False],
#        [11440, 4, 1, 2, 1, False, True, True, False, False, True, True,
#         False, True, False, False, True, False, True, False],
#        [3180, 3, 2, 2, 2, False, True, True, False, True, False, True,
#         False, True, False, True, False, False, True, False],
#        [4500, 4, 2, 1, 2, True, False, True, False, False, True, True,
#         False, False, True, True, False, False, True, False],
#        [6040, 3, 1, 1, 2, False, True, True, False, True, False, True,
#         False, True, False, False, True, False, True, False],
#        [4880, 3, 1, 1, 2, False, True, True, False, True, False, True,
#         False, True, False, False, True, False, False, True],
# ...

# %%
y_train[0:10]
# Out:
# array([4690000, 5950000, 7343000, 5215000, 5215000, 4830000, 4403000,
#        3500000, 2310000, 5250000], dtype=int64)

# %%
## Running the Linear Regression
from sklearn.linear_model import LinearRegression
RegModel = LinearRegression()

print(RegModel)

LREG=RegModel.fit(X_train,y_train)

from sklearn import metrics

print('R2 Value:',metrics.r2_score(y_train, LREG.predict(X_train)))


print('\n##### Model Validation and Accuracy Calculations ##########')


prediction=LREG.predict(X_test)
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)


TestingDataResults['APE']=100 * ((abs(
  TestingDataResults['price']-TestingDataResults['Predictedprice']))/TestingDataResults['price'])


print(TestingDataResults[[TargetVariable,'Predicted'+TargetVariable, 'APE']].head())


MAPE=np.mean(TestingDataResults['APE'])
MedianMAPE=np.median(TestingDataResults['APE'])

Accuracy =100 - MAPE
MedianAccuracy=100- MedianMAPE
print('Mean Accuracy on test data:', Accuracy) 
print('Median Accuracy on test data:', MedianAccuracy)


def Accuracy_Score(orig,pred):
    MAPE = np.mean(100 * (np.abs(orig-pred)/orig))
    return(100-MAPE)


from sklearn.metrics import make_scorer
custom_Scoring=make_scorer(Accuracy_Score, greater_is_better=True)


from sklearn.model_selection import cross_val_score



Accuracy_Values=cross_val_score(RegModel, X , y, cv=5, scoring=custom_Scoring)
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_Values.mean(),2))
# Out:
# LinearRegression()
# R2 Value: 0.7075872135882179
#
# ##### Model Validation and Accuracy Calculations ##########
#      price  Predictedprice         APE
# 0  3115000       3101705.0    0.426806
# 1  5040000       5297023.0    5.099663
# 2  2660000       5392073.0  102.709511
# 3  5145000       3949055.0   23.244801
# 4  3780000       3776098.0    0.103228
# Mean Accuracy on test data: 81.83250445846572
# Median Accuracy on test data: 85.81526540722996
#
# Accuracy values for 10-fold Cross Validation:
#  [72.37333634 85.23041361 83.450187   79.726762   67.76256158]
#
# Final Average Accuracy of the model: 77.71

# %%
LREG.coef_
# Out:
# array([2952887.59918024,  441759.86541922, 3376559.48882708,
#        1231322.95519029,  893390.07683102, -203755.78273024,
#         203755.78273024, -134331.33663836,  134331.33663836,
#        -238364.96261497,  238364.96261497, -307212.39459935,
#         307212.39459935, -341797.65708013,  341797.65708013,
#        -249495.50790829,  249495.50790829,  166186.29975493,
#          49394.80582708, -215581.10558201])

# %%
LREG.intercept_
# Out:
# 3404811.63235915
